# %%
# IMPORTS
import io
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import scipy.io as sio
import GDI
import seaborn as sns

plt.rcParams.update({'font.size': 14});
# Out:
# /Users/joe/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# PARAMETERS
M           = 3
bin_width   = 50
boot_iter   = 5

# %%
# LOAD CPG SPIKES (BINNED AT 0.2 ms RESOLUTION)
binned_spikes = sio.loadmat('cpg.mat')['spike_times_binned']
time = sio.loadmat('cpg.mat')['time'][0,:]
time_max = np.max(time)
neuron_names = ["CBI2","B4","B8","B20","B30","B31a","B34","B40",
                "B51a","B52","B63","B64a","B65"]

# %%
# PLOT binned_spikes
f, ax = plt.subplots(figsize=(20, 9));
for ii in range(binned_spikes.shape[1]):
    plt.plot(time, ii+1.5-binned_spikes[:,ii], label='Neuron = %i'%(ii+1));

plt.xlim((250,400));
plt.xlabel('Time (s)');
plt.ylabel('Neuron');
plt.gca().invert_yaxis();
plt.yticks(np.arange(binned_spikes.shape[1])+1,neuron_names);
plt.title('CPG Raster');

# %%
# FURTHER BIN SPIKE TIMES
num_bins = np.ceil(time_max/(bin_width*0.001))
range_max = num_bins*(bin_width*0.001)
further_binned_spikes = np.zeros((int(num_bins),binned_spikes.shape[1]))
for ii in range(binned_spikes.shape[1]):
    further_binned_spikes[:,ii], time_further_binned = np.histogram(time[binned_spikes[:,ii].astype(bool)],
                     bins=np.arange(0,range_max+((bin_width*0.001)/2),(bin_width*0.001)))

# CAP BINS TO 1 SPIKE
further_binned_spikes[further_binned_spikes>0]=1

# %%
# PLOT further_binned_spikes
f, ax = plt.subplots(figsize=(20, 9))
for ii in range(further_binned_spikes.shape[1]):
    plt.plot(time_further_binned[:-1]+((bin_width*0.001)/2), ii+1.5-further_binned_spikes[:,ii])

plt.xlim((250,400));
plt.xlabel('Time (s)');
plt.ylabel('Neuron');
plt.gca().invert_yaxis();
plt.yticks(np.arange(binned_spikes.shape[1])+1,neuron_names);
plt.title('Binned CPG Raster');

# %%
# LOAD NORMALIZATION
HMatrix = sio.loadmat('cpg.mat')['HMatrix']

DI_est  = GDI.DI(further_binned_spikes,M,boot_iter)
DI_est_norm = DI_est*(1/np.log(2))/HMatrix
DI_est_norm[DI_est_norm<0.01] = 0

GDI_est = GDI.GDI_mask(further_binned_spikes,M,boot_iter,DI_est_norm>0)
GDI_est_norm = GDI_est*(1/np.log(2))/HMatrix
GDI_est_norm[GDI_est_norm<0]=0
# Out:
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# WARNING: Logging before flag parsing goes to stderr.
# Tester = Classifier, metric = donsker_varadhan
# WARNING: Logging before flag parsing goes to stderr.
# W0928 15:15:44.312190 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/CCMI.py:79: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# WARNING: Logging before flag parsing goes to stderr.
# Tester = Classifier, metric = donsker_varadhan
# W0928 15:15:44.318665 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/CCMI.py:79: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# Tester = Classifier, metric = donsker_varadhan
# W0928 15:15:44.317477 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/CCMI.py:79: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# WARNING: Logging before flag parsing goes to stderr.
#
#
# W0928 15:15:44.331591 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:66: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# WARNING: Logging before flag parsing goes to stderr.
# Tester = Classifier, metric = donsker_varadhan
# W0928 15:15:44.327538 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/CCMI.py:79: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/CCMI.py:79: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# WARNING: Logging before flag parsing goes to stderr.
#
#
#
#
#
#
# W0928 15:23:02.736344 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:66: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
# W0928 15:23:02.731299 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/CCMI.py:79: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# W0928 15:23:02.739395 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:66: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
#
# W0928 15:23:02.744103 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:66: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0928 15:23:02.747911 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:49: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
# W0928 15:23:02.748260 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:49: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0928 15:23:02.749680 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:49: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
# W0928 15:23:02.752218 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:66: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
#
# W0928 15:23:02.754255 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:49: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
#
#
# W0928 15:23:02.766480 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:49: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0928 15:23:02.783301 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:49: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0928 15:23:02.759996 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:49: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
# W0928 15:23:02.793706 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:49: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
#
# W0928 15:23:03.656190 4483055040 deprecation.py:323] From /Users/joe/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.whereW0928 15:23:03.659046 4483055040 deprecation.py:323] From /Users/joe/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# W0928 15:23:03.669198 4483055040 deprecation.py:323] From /Users/joe/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0928 15:23:03.677463 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:71: The name tf.losses.get_regularization_loss is deprecated. Please use tf.compat.v1.losses.get_regularization_loss instead.
#
# W0928 15:23:03.674731 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:71: The name tf.losses.get_regularization_loss is deprecated. Please use tf.compat.v1.losses.get_regularization_loss instead.
# W0928 15:23:03.681666 4483055040 deprecation.py:323] From /Users/joe/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
#
# W0928 15:23:03.690645 4483055040 deprecation.py:323] From /Users/joe/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.whereW0928 15:23:03.695240 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:81: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
#
# W0928 15:23:03.706321 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:71: The name tf.losses.get_regularization_loss is deprecated. Please use tf.compat.v1.losses.get_regularization_loss instead.
# W0928 15:23:03.709135 4483055040 deprecation.py:323] From /Users/joe/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.whereW0928 15:23:03.711966 4483055040 deprecation.py:323] From /Users/joe/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.whereW0928 15:23:03.712400 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:71: The name tf.losses.get_regularization_loss is deprecated. Please use tf.compat.v1.losses.get_regularization_loss instead.
#
#
#
#
# W0928 15:23:03.715904 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:81: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0928 15:23:03.721221 4483055040 deprecation.py:323] From /Users/joe/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0928 15:23:03.707849 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:71: The name tf.losses.get_regularization_loss is deprecated. Please use tf.compat.v1.losses.get_regularization_loss instead.
# W0928 15:23:03.734996 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:81: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
#
# W0928 15:23:03.745286 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:71: The name tf.losses.get_regularization_loss is deprecated. Please use tf.compat.v1.losses.get_regularization_loss instead.
#
# W0928 15:23:03.739500 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:71: The name tf.losses.get_regularization_loss is deprecated. Please use tf.compat.v1.losses.get_regularization_loss instead.
# W0928 15:23:03.748360 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:71: The name tf.losses.get_regularization_loss is deprecated. Please use tf.compat.v1.losses.get_regularization_loss instead.
# W0928 15:23:03.759430 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:81: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
# W0928 15:23:03.754055 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:81: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0928 15:23:03.765838 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:81: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
#
#
#
# W0928 15:23:03.788429 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:81: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0928 15:23:03.792086 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:81: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W0928 15:23:04.241374 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:84: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0928 15:23:04.251288 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:87: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# W0928 15:23:04.253740 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:84: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
#
# W0928 15:23:04.265502 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:87: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# W0928 15:23:04.265893 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:84: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
#
# W0928 15:23:04.269081 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:84: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# W0928 15:23:04.269744 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:84: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# W0928 15:23:04.271811 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:87: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
#
#
# W0928 15:23:04.276433 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:87: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# W0928 15:23:04.277698 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:87: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
#
# W0928 15:23:04.284801 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:84: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# W0928 15:23:04.288325 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:84: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
#
# W0928 15:23:04.300554 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:87: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# W0928 15:23:04.301759 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:87: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
#
# W0928 15:23:04.308965 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:84: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0928 15:23:04.317939 4483055040 deprecation_wrapper.py:119] From /Users/joe/GDI_Code_Dev/Classifier_MI.py:87: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# Tester = Classifier, metric = donsker_varadhan
# /Users/joe/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':
# /Users/joe/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in less
#   # Remove the CWD from sys.path while we load stuff.

# %%
GDI_sign, DI_sign = GDI.sign_inference(further_binned_spikes,M)

DI_est_norm_signed = DI_est_norm*DI_sign
GDI_est_norm_signed = GDI_est_norm*GDI_sign
# Out:
# 0
#
# [[-1.00000000e+00 -1.00000000e+00 -1.00000000e+00]
#  [-8.70633415e-02 -8.34482940e-02 -7.97679012e-02]
#  [-1.50640095e-02 -6.22195796e-04 -1.98120855e-02]
#  [ 1.64280486e-02 -2.97617112e-03 -1.42899693e-03]
#  [ 5.38033308e-03 -1.81872839e-03 -6.84436086e-03]
#  [-2.01692542e-02  2.74162027e-02 -2.82626171e-02]
#  [ 5.38283893e-03 -1.02478852e-02  2.15417883e-02]
#  [-2.69219434e-02  1.98550330e-02  9.29158315e-02]
#  -0.02000098]
# [-0.1390729   0.33966399  0.0871166  -0.03395342 -0.02229984 -0.02695769
#  -0.01402465 -0.06711113  0.20954923 -0.0713478  -0.07075562  1.
#  -0.03521276]
#
# 12
#
# [[ 0.01143264  0.01299367 -0.00991364]
#  [-0.02461971 -0.01694336 -0.01681906]
#  [ 0.08765373  0.03490982 -0.00387623]
#  [ 0.0372475   0.23647541  0.01487945]
#  [ 0.11399954  0.01724016  0.01592962]
#  [ 0.05780118  0.03947215  0.13310445]
#  [ 0.00805448 -0.05363749  0.08133838]
#  [ 0.00356329 -0.02331817 -0.00424406]
#  [-0.01909044 -0.01110166 -0.01029268]
#  [-0.0183266  -0.01610121 -0.01922999]
#  [-0.01784761  0.03117406  0.02025674]
#  [-0.02826538 -0.020282   -0.0226257 ]
#  [-1.         -1.         -1.        ]]
#
# [[ 0.01880327  0.02205066  0.00252729]
#  [-0.03149351 -0.03149764 -0.03150178]
#  [ 0.12205241  0.11045973  0.05830086]
#  [ 0.09871767  0.29076073  0.09871436]
#  [ 0.12751223  0.04169715  0.04169572]
#  [ 0.07891052  0.06620239  0.15515012]
#  [ 0.1052441   0.12849034  0.14011289]
#  [ 0.00924445 -0.01530682  0.00310197]
#  [-0.02462337 -0.02462655 -0.02462973]
#  [-0.02279171 -0.02279464 -0.02279758]
#  [ 0.02837278  0.13511929  0.06039175]
#  [-0.03521276 -0.03521743 -0.0352221 ]
#  [ 1.          1.          1.        ]]
#
# [ 0.01299367 -0.02461971  0.08765373  0.23647541  0.11399954  0.13310445
#   0.08133838 -0.02331817 -0.01909044 -0.01922999  0.03117406 -0.02826538
#  -1.        ]
# [ 0.02205066 -0.03150178  0.12205241  0.29076073  0.12751223  0.15515012
#   0.14011289 -0.01530682 -0.02462973 -0.02279758  0.13511929 -0.0352221
#   1.        ]

# %%
# Load true connectivity structure
true_conn = sio.loadmat('cpg.mat')['C']

# Plot true connectivity structure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the correct aspect ratio
sns.heatmap(true_conn, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.yticks(np.arange(binned_spikes.shape[1])+0.5,neuron_names);
plt.xticks(np.arange(binned_spikes.shape[1])+0.5,neuron_names);

plt.title('Connectivity')
# Out:
# Text(0.5,1,'Connectivity')

# %%
# Plot DI
f, ax = plt.subplots(figsize=(11, 9))

# Draw the heatmap with the correct aspect ratio
sns.heatmap(DI_est_norm_signed, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.yticks(np.arange(binned_spikes.shape[1])+0.5,neuron_names);
plt.xticks(np.arange(binned_spikes.shape[1])+0.5,neuron_names);

plt.title('Estimated DI')
# Out:
# Text(0.5,1,'Estimated DI')

# %%
# Plot GDI
f, ax = plt.subplots(figsize=(11, 9))

# Draw the heatmap with the correct aspect ratio
sns.heatmap(GDI_est_norm_signed, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.yticks(np.arange(binned_spikes.shape[1])+0.5,neuron_names);
plt.xticks(np.arange(binned_spikes.shape[1])+0.5,neuron_names);

plt.title('Estimated GDI')
# Out:
# Text(0.5,1,'Estimated GDI')
